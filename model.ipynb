# %% [markdown]
# # Prediction Model

# %%
# importing librairies ...
import pandas as pd

# %%
# The first step is to retrieve cleaned data 
df18 = pd.read_csv('./dataset/immoCollect18-clean.csv')
df52 = pd.read_csv('./dataset/immoCollect52-clean.csv')

# %%
df18.head()

# %%
df52.head()

# %%
df18.head()
# Out:
#    Unnamed: 0    Prix  Type de propriété  Bien neuf  Code Postal  \
# 0           0  280000                  0       True         1180
# 1           1  282500                  0       True         1180
# 2           2  412500                  0       True         1180
# 3           3  380000                  0       True         1160
# 4           4  165000                  0       True         6000
#
#    Surface habitable  Nombre de chambre(s)  Jardin  Terrasse
# 0                 65                     1    True      True
# 1                 73                     1   False      True
# 2                100                     2   False      True
# 3                 87                     2   False      True
# 4                 63                     1   False     False

# %%
df52.head()
# Out:
#    Unnamed: 0  postal_code  type_of_property   price  number_of_rooms  \
# 0           5         1650                 0  525000                4
# 1          18         7850                 0  550000                4
# 2          19         4020                 0   85000                2
# 3          21         1700                 0  525000                4
# 4          22         4000                 0  150000                4
#
#    house_area  fully_equipped_kitchen  terrace  garden  state_of_the_building  \
# 0         220                       1        1       1                      0
# 1         276                       1        1       1                      1
# 2         110                       1        0       0                      0
# 3         260                       1        1       1                      0
# 4         247                       1        1       0                      0
#
#    ...  locality              province           region     head_city  \
# ...
